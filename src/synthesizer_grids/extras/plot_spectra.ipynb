# %% [markdown]
# # Plotting spectra

# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
grid_dir = "/Users/sw376/Dropbox/Research/data/synthesizer/grids"
grid_name = "bpass-2.2.1-bin_chabrier03-0.1,300.0"
grid_name = "bc03_chabrier03-0.1,100"
grid_name = "feltre16"
grid_name = "agnsed"
grid_name = "qsosed-isotropic-limited"

# %% [markdown]
# #### Open

# %%
grid = h5py.File(f"{grid_dir}/{grid_name}.hdf5")
print(grid.attrs["axes"])
# Out:
# ['mass' 'accretion_rate_eddington']

# %% [markdown]
# #### Plot single spectra

# %%
grid_point = tuple(np.zeros(grid.attrs["axes"].shape, dtype=np.int8))

lam = grid["spectra/wavelength"][()]
lnu = grid["spectra/incident"][grid_point]




plt.plot(np.log10(lam), np.log10(lnu))
plt.ylim(np.max(np.log10(lnu)) - 4, np.max(np.log10(lnu)) + 0.2)
plt.show()
# Out:
# /var/folders/1r/dyc06cz53k1g87b17q09by98000ft2/T/ipykernel_12078/116099653.py:6: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(lam), np.log10(lnu))
# /var/folders/1r/dyc06cz53k1g87b17q09by98000ft2/T/ipykernel_12078/116099653.py:7: RuntimeWarning: divide by zero encountered in log10
#   plt.ylim(np.max(np.log10(lnu)) - 4, np.max(np.log10(lnu)) + 0.2)

# %% [markdown]
# ## Plot extremes
#
# Plot all the corners (2^N)

# %%
print(grid.attrs["axes"])

grid_point = tuple(np.zeros(grid.attrs["axes"].shape, dtype=np.int8))

print(grid_point)

lam = grid["spectra/wavelength"][()]
lnu = grid["spectra/incident"][grid_point]

plt.plot(np.log10(lam), np.log10(lnu))
plt.ylim(np.max(np.log10(lnu)) - 4, np.max(np.log10(lnu)) + 0.2)
plt.show()
# Out:
# ['mass' 'accretion_rate_eddington']
# (np.int8(0), np.int8(0))
# /var/folders/1r/dyc06cz53k1g87b17q09by98000ft2/T/ipykernel_12078/3838559006.py:10: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(lam), np.log10(lnu))
# /var/folders/1r/dyc06cz53k1g87b17q09by98000ft2/T/ipykernel_12078/3838559006.py:11: RuntimeWarning: divide by zero encountered in log10
#   plt.ylim(np.max(np.log10(lnu)) - 4, np.max(np.log10(lnu)) + 0.2)
