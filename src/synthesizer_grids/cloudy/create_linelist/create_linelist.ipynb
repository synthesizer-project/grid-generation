# %% [markdown]
# # Linelist generator
#
# This is a simple notebook to generate a reduced linelist for use by `cloudy` in the grid creation process. This works by analysing various cloudy models including stellar and AGN models at different metallicity and then combining the line lists where lines are bright enough in at least one model.

# %%
import numpy as np
from synthesizer.photoionisation import cloudy23

# %%
# define the wavelength type, either standard or just using vacuum wavelengths.
wavelength_type = 'standard'
# wavelength_type = 'vacuum'

# define the reference line to use, by default here we use Hbeta
if wavelength_type == 'standard':
    reference_line = 'H 1 4861.32A'
if wavelength_type == 'vacuum':
    reference_line = 'H 1 4862.69A'

# log constrast relative to Hbeta to consider, i.e. only include lines
# which are within this value of the reference line.
contrast_stars = -1.5
contrast_agn = -1.5

# minimum wavelength of lines to consider
min_wavelength = 1000

# maximum wavelength of lines to consider
max_wavelength = 25000

# %% [markdown]
# ### Stellar models
#
# Read in AGN model line lists and identify lines above the threshold.

# %%
linelist = []

model = r'stellar_'+wavelength_type
for i in range(1):
    i += 1
    line_ids, blends, wavelengths, intrinsic, emergent = (
        cloudy23.read_lines(rf'{model}/{i}'))
    Hbeta = emergent[line_ids==reference_line][0]
    s = ((emergent > (Hbeta + contrast_stars)) & (wavelengths<max_wavelength)
         & (wavelengths>min_wavelength) & np.logical_not(blends))
    print(i, np.sum(s))
    linelist += list(line_ids[s])
# Out:
# 1 196

# %% [markdown]
# ### AGN models
#
# Read in AGN model line lists and identify lines above the threshold.

# %%
model = r'relagn_'+wavelength_type

for i in range(3):
    i += 1
    line_ids, blends, wavelengths, intrinsic, emergent = (
        cloudy23.read_lines(rf'{model}/{i}'))
    Hbeta = emergent[line_ids==reference_line][0]
    s = ((emergent > (Hbeta + contrast_agn)) & (wavelengths<max_wavelength)
         & (wavelengths>min_wavelength) & np.logical_not(blends))
    print(i, np.sum(s))
    linelist += list(line_ids[s])

# %% [markdown]
# # Add additional lines
# If you want additional lines that might not satisfy the Hbeta
# constrast add them in `extra_lines.dat`. They should be picked from
# cloudy list of lines and not be arbitrary.

# %%
with open(f"extra_lines.dat", "r") as f:
    extra_lines = [line.rstrip() for line in f]
linelist += list(extra_lines)
linelist.sort()
print (linelist)
# Out:
# ['"^13CO"  1359.86m', '"^13CO"  2719.67m', '"^13CO"  679.978m', '"^13CO"  906.599m', np.str_('Al 2 1670.79A'), np.str_('Al 2 2669.15A'), np.str_('Al 3 1854.72A'), np.str_('Al 3 1862.79A'), np.str_('Ar 3 7135.79A'), np.str_('Ar 3 7751.11A'), np.str_('Ar 4 2853.66A'), np.str_('Ar 4 4740.12A'), np.str_('C 2 1036.34A'), np.str_('C 2 1037.02A'), np.str_('C 2 1334.53A'), np.str_('C 2 1335.71A'), 'C 2 157.636m', np.str_('C 2 2325.40A'), np.str_('C 2 2326.93A'), np.str_('C 2R 1335.00A'), np.str_('C 3 1906.68A'), np.str_('C 3 1908.73A'), np.str_('C 3R 1909.00A'), np.str_('C 4 1548.19A'), np.str_('C 4 1550.77A'), 'CO  1300.05m', 'CO  2600.05m', 'CO  371.549m', 'CO  433.438m', 'CO  520.089m', 'CO  650.074m', 'CO  866.727m', np.str_('Ca 5 5309.11A'), np.str_('Fe 2 1.25668m'), np.str_('Fe 2 1.53348m'), np.str_('Fe 2 1.59948m'), np.str_('Fe 2 1.64355m'), np.str_('Fe 2 1.66377m'), np.str_('Fe 2 1.67688m'), np.str_('Fe 2 1.71113m'), np.str_('Fe 2 1.74494m'), np.str_('Fe 2 1.79711m'), np.str_('Fe 2 1.80002m'), np.str_('Fe 2 1.80940m'), np.str_('Fe 2 2382.04A'), np.str_('Fe 2 2493.30A'), np.str_('Fe 2 2611.87A'), np.str_('Fe 2 2625.67A'), np.str_('Fe 2 2926.59A'), np.str_('Fe 2 3277.35A'), np.str_('Fe 2 4243.97A'), np.str_('Fe 2 4287.39A'), np.str_('Fe 2 4359.33A'), np.str_('Fe 2 5158.79A'), np.str_('Fe 2 5261.63A'), np.str_('Fe 2 7155.17A'), np.str_('Fe 2 7172.00A'), np.str_('Fe 2 7388.17A'), np.str_('Fe 2 7452.56A'), np.str_('Fe 2 8616.95A'), np.str_('Fe 2 8891.93A'), np.str_('Fe 2 9051.95A'), np.str_('Fe 2 9226.63A'), np.str_('Fe 2b 1.03250m'), np.str_('Fe 2b 1.88900m'), np.str_('Fe 2b 10000.0A'), np.str_('Fe 2b 2355.00A'), np.str_('Fe 2b 2430.00A'), np.str_('Fe 2b 2445.00A'), np.str_('Fe 2b 2495.00A'), np.str_('Fe 2b 2500.00A'), np.str_('Fe 2b 2610.00A'), np.str_('Fe 2b 2758.00A'), np.str_('Fe 2b 2780.00A'), np.str_('Fe 2b 2935.00A'), np.str_('Fe 2b 2960.00A'), np.str_('Fe 2b 3180.00A'), np.str_('Fe 2b 3250.00A'), np.str_('Fe 2b 4255.00A'), np.str_('Fe 2b 4558.00A'), np.str_('Fe 2b 4600.00A'), np.str_('Fe 2b 4855.00A'), np.str_('Fe 2b 4920.00A'), np.str_('Fe 2b 4971.00A'), np.str_('Fe 2b 4975.00A'), np.str_('Fe 2b 5000.00A'), np.str_('Fe 2b 5070.00A'), np.str_('Fe 2b 5143.00A'), np.str_('Fe 2b 5270.00A'), np.str_('Fe 2b 5318.00A'), np.str_('Fe 2b 5540.00A'), np.str_('Fe 2b 7000.00A'), np.str_('Fe 2b 7445.00A'), np.str_('Fe 2b 8625.00A'), np.str_('Fe 3 4658.05A'), np.str_('Fe 3 4701.53A'), np.str_('Fe 3 5270.40A'), np.str_('Fe 4 2567.61A'), np.str_('Fe 4 2829.36A'), np.str_('Fe 4 2835.74A'), np.str_('Fe 4 4906.56A'), np.str_('Fe 5 3794.94A'), np.str_('Fe 5 3839.27A'), np.str_('Fe 5 3891.28A'), np.str_('Fe 5 3895.22A'), np.str_('Fe 5 4071.24A'), np.str_('Fe 6 3662.50A'), np.str_('Fe 6 4967.14A'), np.str_('Fe 6 4972.47A'), np.str_('Fe 6 5145.75A'), np.str_('Fe 6 5176.04A'), np.str_('Fe 6 5335.18A'), np.str_('Fe 6 5424.22A'), np.str_('Fe 6 5631.07A'), np.str_('Fe 6 5676.95A'), np.str_('Fe 7 3758.92A'), np.str_('Fe 7 5720.71A'), np.str_('Fe 7 6086.97A'), np.str_('H 1 1.00494m'), np.str_('H 1 1.09381m'), np.str_('H 1 1.28181m'), np.str_('H 1 1.87510m'), np.str_('H 1 1215.67A'), np.str_('H 1 3734.37A'), np.str_('H 1 3750.15A'), np.str_('H 1 3770.63A'), np.str_('H 1 3797.90A'), np.str_('H 1 3835.38A'), np.str_('H 1 3889.05A'), np.str_('H 1 3970.07A'), np.str_('H 1 4101.73A'), np.str_('H 1 4340.46A'), np.str_('H 1 4861.32A'), np.str_('H 1 6562.80A'), np.str_('H 1 9545.97A'), 'HCN  1127.22m', 'HCN  1690.78m', 'HCN  1690.80m', 'HCN  1690.82m', 'HCN  3381.44m', 'HCN  3381.52m', 'HCN  3381.58m', 'HCN  375.844m', 'HCN  422.796m', 'HCN  483.168m', 'HCN  563.665m', 'HCN  676.373m', 'HCN  845.428m', 'HCO+  1120.18m', 'HCO+  1680.21m', 'HCO+  3360.43m', 'HCO+  560.140m', 'HCO+  672.144m', 'HCO+  840.150m', np.str_('He 1 1.08291m'), np.str_('He 1 1.08303m'), np.str_('He 1 1.08303m'), np.str_('He 1 3888.64A'), np.str_('He 1 5875.61A'), np.str_('He 1 5875.64A'), np.str_('He 1 7065.18A'), np.str_('He 1 7065.22A'), np.str_('He 2 1.01235m'), np.str_('He 2 1025.27A ...

# %%
linelist = list(set(linelist))
linelist.sort()

print(len(linelist))

linelist_ = []

for line in linelist:

    element, ion, wavelength = line.split(' ')

    if len(ion)==1:

        line_ = f'{element} {ion} {wavelength}'
        print(line_)
        linelist_.append(line_)
    
    elif len(ion)==0:
        
        line_ = f'{element} {wavelength}'
        print(line_)
        linelist_.append(line_)

with open(f'linelist-{wavelength_type}1.dat', 'w') as file:
    file.writelines('\n'.join(linelist_) + '\n')
# Out:
# 234
# "^13CO" 1359.86m
# "^13CO" 2719.67m
# "^13CO" 679.978m
# "^13CO" 906.599m
# Al 2 1670.79A
# Al 2 2669.15A
# Al 3 1854.72A
# Al 3 1862.79A
# Ar 3 7135.79A
# Ar 3 7751.11A
# Ar 4 2853.66A
# Ar 4 4740.12A
# C 2 1036.34A
# C 2 1037.02A
# C 2 1334.53A
# C 2 1335.71A
# C 2 157.636m
# C 2 2325.40A
# C 2 2326.93A
# C 3 1906.68A
# C 3 1908.73A
# C 4 1548.19A
# C 4 1550.77A
# CO 1300.05m
# CO 2600.05m
# CO 371.549m
# CO 433.438m
# CO 520.089m
# CO 650.074m
# CO 866.727m
# Ca 5 5309.11A
# Fe 2 1.25668m
# Fe 2 1.53348m
# Fe 2 1.59948m
# Fe 2 1.64355m
# Fe 2 1.66377m
# Fe 2 1.67688m
# Fe 2 1.71113m
# Fe 2 1.74494m
# Fe 2 1.79711m
# Fe 2 1.80002m
# Fe 2 1.80940m
# Fe 2 2382.04A
# Fe 2 2493.30A
# Fe 2 2611.87A
# Fe 2 2625.67A
# Fe 2 2926.59A
# Fe 2 3277.35A
# Fe 2 4243.97A
# Fe 2 4287.39A
# Fe 2 4359.33A
# Fe 2 5158.79A
# Fe 2 5261.63A
# Fe 2 7155.17A
# Fe 2 7172.00A
# Fe 2 7388.17A
# Fe 2 7452.56A
# Fe 2 8616.95A
# Fe 2 8891.93A
# Fe 2 9051.95A
# Fe 2 9226.63A
# Fe 3 4658.05A
# Fe 3 4701.53A
# Fe 3 5270.40A
# Fe 4 2567.61A
# Fe 4 2829.36A
# Fe 4 2835.74A
# Fe 4 4906.56A
# Fe 5 3794.94A
# Fe 5 3839.27A
# Fe 5 3891.28A
# Fe 5 3895.22A
# Fe 5 4071.24A
# Fe 6 3662.50A
# Fe 6 4967.14A
# Fe 6 4972.47A
# Fe 6 5145.75A
# Fe 6 5176.04A
# Fe 6 5335.18A
# Fe 6 5424.22A
# Fe 6 5631.07A
# Fe 6 5676.95A
# Fe 7 3758.92A
# Fe 7 5720.71A
# Fe 7 6086.97A
# H 1 1.00494m
# H 1 1.09381m
# H 1 1.28181m
# H 1 1.87510m
# H 1 1215.67A
# H 1 3734.37A
# H 1 3750.15A
# H 1 3770.63A
# H 1 3797.90A
# H 1 3835.38A
# H 1 3889.05A
# H 1 3970.07A
# H 1 4101.73A
# H 1 4340.46A
# H 1 4861.32A
# H 1 6562.80A
# H 1 9545.97A
# HCN 1127.22m
# HCN 1690.78m
# HCN 1690.80m
# HCN 1690.82m
# HCN 3381.44m
# HCN 3381.52m
# HCN 3381.58m
# HCN 375.844m
# HCN 422.796m
# HCN 483.168m
# HCN 563.665m
# HCN 676.373m
# HCN 845.428m
# HCO+ 1120.18m
# HCO+ 1680.21m
# HCO+ 3360.43m
# HCO+ 560.140m
# HCO+ 672.144m
# HCO+ 840.150m
# He 1 1.08291m
# He 1 1.08303m
# He 1 3888.64A
# He 1 5875.61A
# He 1 5875.64A
# He 1 7065.18A
# He 1 7065.22A
# He 2 1.01235m
# He 2 1025.27A
# He 2 1084.94A
# He 2 1215.13A
# He 2 1640.41A
# He 2 2733.28A
# He 2 3203.08A
# He 2 4685.68A
# Mg 2 2795.53A
# Mg 2 2802.71A
# Mg 5 2782.76A
# N 2 121.767m
# N 2 205.244m
# N 2 6548.05A
# N 2 6583.45A
# N 3 1749.67A
# N 3 1752.16A
# N 3 57.3238m
# N 4 1486.50A
# N 5 1238.82A
# Ne 3 3868.76A
# Ne 3 3967.47A
# Ne 4 1601.45A
# Ne 4 2421.66A
# Ne 5 3345.82A
# Ne 5 3425.88A
# Ni 2 7377.83A
# O 1 1302.17A
# O 1 1304.86A
# O 1 1306.03A
# O 1 145.495m
# O 1 63.1679m
# O 1 6300.30A
# O 1 6363.78A
# O 2 2470.34A
# O 2 7319.99A
# O 2 7329.67A
# O 2 7330.73A
# O 3 1660.81A
# O 3 1666.15A
# O 3 2320.95A
# O 3 4363.21A
# O 3 4958.91A
# O 3 5006.84A
# O 3 51.8004m
# O 3 88.3323m
# O 4 1401.16A
# O 4 1404.81A
# O 4 25.8832m
# O 5 1218.34A
# S 2 4068.60A
# S 3 3721.63A
# S 3 6312.06A
# S 3 9068.62A
# S 3 9530.62A
# Si 2 1179.59A
# Si 2 1190.42A
# Si 2 1193.29A
# Si 2 1194.50A
# Si 2 1197.39A
# Si 2 1260.42A
# Si 2 1264.74A
# Si 2 1265.00A
# Si 2 1526.71A
# Si 2 1533.43A
# Si 2 1816.93A
# Si 2 2334.60A
# Si 2 2344.20A
# Si 3 1206.50A
# Si 3 1892.03A
# Si 4 1393.75A
# Si 4 1402.77A
# Si 6 1.96247m

# %% [markdown]
# ## Convert between standard and vacuum wavelengths

# %%
def vacuum_to_air(wave):

    """
    Function to convert vaccum wavelengths to air wavelengths.
    """

    wave2 = wave**2.0

    fact = 1.0 + 2.735182e-4 + 131.4182 / wave2 + 2.76249e8 / (wave2**2.0)

    fact = fact * (wave >= 2000.0) + 1.0 * (wave < 2000.0)

    wave = wave / fact

    return wave

def air_to_vacuum(wave):

    """
    Function to convert air wavelengths to vacuum wavelengths.
    """

    sigma2 = (1.0e4 / wave) ** 2.0  # Convert to wavenumber squared

    # Compute conversion factor

    fact = (1.0 + 6.4328e-5 + 2.94981e-2 / (146.0 - sigma2)
            + 2.5540e-4 / (41.0 - sigma2))

    fact = fact * (wave >= 2000.0) + 1.0 * (wave < 2000.0)

    wave = wave * fact  # Convert Wavelength

    return wave


air_to_vacuum(vacuum_to_air(4365.))

# %%
# check this works correctly

standard = open('linelist-standard.dat', 'r').readlines()
vacuum = open('linelist-vacuum.dat', 'r').readlines()

print(standard)

for standard_, vacuum_ in zip(standard, vacuum):

    # remove escape character
    standard_ = standard_[:-1]
    vacuum_ = vacuum_[:-1]

    element, ion, wavelength = standard_.split(' ')

    wavelength_ = float(wavelength[:-1])
    wavelength_unit = wavelength[-1]

    # convert to vacuum
    new_vacuum = (
        f'{element} {ion}'
        f'{air_to_vacuum(wavelength_):.6g}{wavelength_unit}'
    )

    print(standard_, wavelength_,
          wavelength_unit, '|', new_vacuum, '|', vacuum_)
